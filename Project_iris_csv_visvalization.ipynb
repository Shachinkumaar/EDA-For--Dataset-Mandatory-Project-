# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.countplot(x='species',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
df.plot(kind='scatter',x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.countplot(x='',hue='species',data=df,palette='RdBu_r')

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="species", size=4) \
   .map(pyplot.scatter, "sepal_length", "sepal_width") \
   .add_legend();
pyplot.show();
# Out:
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
pyplot.close();
sns.set_style("whitegrid");
sns.pairplot(df, hue="species", size=5);
pyplot.show()
# Out:
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#1D scatter plot
import numpy as np
df_setosa = df.loc[df["species"] == "setosa"];
df_virginica = df.loc[df["species"] == "virginica"];
df_versicolor = df.loc[df["species"] == "versicolor"];
#print(df_setosa["petal_length"])
pyplot.plot(df_setosa["petal_length"], np.zeros_like(df_setosa['petal_length']), 'o')
pyplot.plot(df_versicolor["petal_length"], np.zeros_like(df_versicolor['petal_length']), 'o')
pyplot.plot(df_virginica["petal_length"], np.zeros_like(df_virginica['petal_length']), 'o')

pyplot.show()

# %%
#distribution based on petal length,sl,pw,sw
sns.FacetGrid(df, hue="species", size=5) \
   .map(sns.distplot, "petal_length") \
   .add_legend();
pyplot.show();
# Out:
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(df, hue="species", size=5) \
   .map(sns.distplot, "sepal_length") \
   .add_legend();
pyplot.show();
# Out:
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(df, hue="species", size=5) \
   .map(sns.distplot, "sepal_width") \
   .add_legend();
pyplot.show();
# Out:
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.FacetGrid(df, hue="species", size=5) \
   .map(sns.distplot, "petal_width") \
   .add_legend();
pyplot.show();
# Out:
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SHACH\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df_setosa = df.loc[df["species"] == "setosa"].median()
df_setosa
# Out:
# C:\Users\SHACH\AppData\Local\Temp/ipykernel_22412/3574343026.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_setosa = df.loc[df["species"] == "setosa"].median()
# sepal_length    5.0
# sepal_width     3.4
# petal_length    1.5
# petal_width     0.2
# dtype: float64

# %%
df_setosa = df.loc[df["species"] == "setosa"].mean()
df_setosa
# Out:
# C:\Users\SHACH\AppData\Local\Temp/ipykernel_22412/1523638388.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_setosa = df.loc[df["species"] == "setosa"].mean()
# sepal_length    5.006
# sepal_width     3.418
# petal_length    1.464
# petal_width     0.244
# dtype: float64

# %%
# boxplot

# %%
pyplot.figure(figsize=(10, 7))
sns.boxplot(x='species',y="petal_width",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
pyplot.figure(figsize=(10, 7))
sns.boxplot(x='species',y="petal_length",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
pyplot.figure(figsize=(10, 7))
sns.boxplot(x='species',y="sepal_width",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
pyplot.figure(figsize=(10, 7))
sns.boxplot(x='species',y="sepal_length",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
#violinplot

# %%
pyplot.figure(figsize=(10, 7))
sns.violinplot(x='species',y="petal_width",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
pyplot.figure(figsize=(10, 7))
sns.violinplot(x='species',y="petal_length",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
pyplot.figure(figsize=(10, 7))
sns.violinplot(x='species',y="sepal_width",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_width'>

# %%
pyplot.figure(figsize=(10, 7))
sns.violinplot(x='species',y="sepal_length",data=df,palette='winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
# jointplot

# %%
pyplot.figure(figsize=(10, 7))
sns.jointplot(x='petal_length',y="sepal_width",data=df,kind='kde')

# %%
pyplot.figure(figsize=(10, 7))
sns.jointplot(x='petal_length',y="sepal_width",data=df,kind='kde')

# %%
pyplot.figure(figsize=(10, 7))
sns.jointplot(x='sepal_length',y="petal_length",data=df,kind='kde')

# %%
pyplot.figure(figsize=(10, 7))
sns.jointplot(x='petal_width',y="sepal_width",data=df,kind='kde')

# %%
#heatmap
pyplot.figure(figsize=(7,4))
sns.heatmap(df.corr(),annot=True,cmap='hot')
# Out:
# <AxesSubplot:>

# %%
# lineplot
pyplot.figure(figsize=(10, 7))
sns.lineplot(x='petal_width',y="sepal_width",data=df)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>
